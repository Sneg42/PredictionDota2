# %%
import pandas as pd
import json

# %%
# запись файла json со словарем имен команд и ID
with open("ID_nameTeam", "w", encoding="utf-8") as file:
    json.dump(a, file)
    file.close

# %%
#Список всех героев с их id на openDota
heroes_list = pd.read_json('https://api.opendota.com/api/heroes').drop(['name', 'legs'], axis=1)
heroes_list['Disabler']=0
heroes_list['Nuker']=0
heroes_list['Carry']=0
heroes_list['Initiator']=0
heroes_list['Escape']=0
heroes_list['Durable']=0
heroes_list['Support']=0
heroes_list['Pusher']=0
heroes_list['Jungler']=0

a = -1
for x in heroes_list['roles']:
    a+=1
    for rol in x:
        if rol == 'Carry':
            heroes_list['Carry'].iloc[a] = 1
        if rol == 'Escape':
            heroes_list['Escape'].iloc[a] = 1
        if rol == 'Disabler':
            heroes_list['Disabler'].iloc[a] = 1
        if rol == 'Nuker':
            heroes_list['Nuker'].iloc[a] = 1
        if rol == 'Initiator':
            heroes_list['Initiator'].iloc[a] = 1
        if rol == 'Durable':
            heroes_list['Durable'].iloc[a] = 1
        if rol == 'Support':
            heroes_list['Support'].iloc[a] = 1
        if rol == 'Pusher':
            heroes_list['Pusher'].iloc[a] = 1
        if rol == 'Jungler':
            heroes_list['Jungler'].iloc[a] = 1

heroes_list.index = heroes_list['id']
#Необходимо чтобы данные записалсиь в основной датафрейм
heroes_list = heroes_list.drop('id', axis=1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#Запись всех героев в файл
heroes_list.to_csv('All_Heroes.csv')

# %%
# Out:
#     attack_type       localized_name primary_attr  \
# id
# 1         Melee            Anti-Mage          agi
# 2         Melee                  Axe          str
# 3        Ranged                 Bane          int
# 4         Melee          Bloodseeker          agi
# 5        Ranged       Crystal Maiden          int
# 6        Ranged          Drow Ranger          agi
# 7         Melee          Earthshaker          str
# 8         Melee           Juggernaut          agi
# 9        Ranged               Mirana          agi
# 10       Ranged            Morphling          agi
# 11       Ranged         Shadow Fiend          agi
# 12        Melee       Phantom Lancer          agi
# 13       Ranged                 Puck          int
# 14        Melee                Pudge          str
# 15       Ranged                Razor          agi
# 16        Melee            Sand King          str
# 17       Ranged         Storm Spirit          int
# 18        Melee                 Sven          str
# 19        Melee                 Tiny          str
# 20       Ranged      Vengeful Spirit          agi
# 21       Ranged           Windranger          int
# 22       Ranged                 Zeus          int
# 23        Melee               Kunkka          str
# 25       Ranged                 Lina          int
# 26       Ranged                 Lion          int
# 27       Ranged        Shadow Shaman          int
# 28        Melee              Slardar          str
# 29        Melee           Tidehunter          str
# 30       Ranged         Witch Doctor          int
# 31       Ranged                 Lich          int
# ..          ...                  ...          ...
# 88        Melee         Nyx Assassin          agi
# 89        Melee           Naga Siren          agi
# 90       Ranged  Keeper of the Light          int
# 91       Ranged                   Io          str
# 92       Ranged               Visage          int
# 93        Melee                Slark          agi
# 94       Ranged               Medusa          agi
# 95       Ranged        Troll Warlord          agi
# 96        Melee    Centaur Warrunner          str
# 97        Melee               Magnus          str
# 98        Melee            Timbersaw          str
# 99        Melee          Bristleback          str
# 100       Melee                 Tusk          str
# 101      Ranged        Skywrath Mage          int
# 102       Melee              Abaddon          str
# 103       Melee          Elder Titan          str
# 104       Melee     Legion Commander          str
# 105      Ranged              Techies          int
# 106       Melee         Ember Spirit          agi
# 107       Melee         Earth Spirit          str
# 108       Melee            Underlord          str
# 109       Melee          Terrorblade          agi
# 110      Ranged              Phoenix          str
# 111      Ranged               Oracle          int
# 112      Ranged        Winter Wyvern          int
# 113      Ranged           Arc Warden          agi
# 114       Melee          Monkey King          agi
# 119      Ranged          Dark Willow          int
# 120       Melee            Pangolier          agi
# 121      Ranged           Grimstroke          int
#
#                                                  roles  Disabler  Nuker  \
# id
# 1                               [Carry, Escape, Nuker]         0      1
# 2              [Initiator, Durable, Disabler, Jungler]         1      0
# 3                  [Support, Disabler, Nuker, Durable]         1      1
# 4         [Carry, Disabler, Jungler, Nuker, Initiator]         1      1
# 5                  [Support, Disabler, Nuker, Jungler]         1      1
# 6                            [Carry, Disabler, Pusher]         1      0
# 7                [Support, Initiator, Disabler, Nuker]         1      1
# 8                              [Carry, Pusher, Escape]         0      0
# 9            [Carry, Support, Escape, Nuker, Disabler]         1      1
# 10           [Carry, Escape, Durable, Nuker, Disabler]         1      1
# 11                                      [Carry, Nuker]         0      1
# 12                      [Carry, Escape, Pusher, Nuker]         0      1
# 13                [Initiator, Disabler, Escape, Nuker]         1      1
# 14               [Disabler, Initiator, Durable, Nuker]         1      1
# 15                     [Carry, Durable, Nuker, Pusher]         0      1
# 16   [Initiator, Disabler, Support, Nuker, Escape, ...         1      1
# 17         [Carry, Escape, Nuker, Initiator, Disabler]         1      1
# 18        [Carry, Disabler, Initiator, Durable, Nuker]         1      1
# 19   [Carry, Nuker, Pusher, Initiator, Durable, Dis...         1      1
# 20       [Support, Initiator, Disabler, Nuker, Escape]         1      1
# 21           [Carry, Support, Disabler, Escape, Nuker]         1      1
# 22                                             [Nuker]         0      1
# 23   [Carry, Support, Disabler, Initiator, Durable,...         1      1
# 25                   [Support, Carry, Nuker, Disabler]         1      1
# 26               [Support, Disabler, Nuker, Initiator]         1      1
# 27       [Support, Pusher, Disabler, Nuker, Initiator]         1      1
# 28       [Carry, Durable, Initiator, Disabler, Escape]         1      0
# 29               [Initiator, Durable, Disabler, Nuker]         1      1
# 30                          [Support, Nuker, Disabler]         1      1
# 31                                    [Support, Nuker]         0      1
# ..                                                 ...       ...    ...
# 88                [Disabler, Nuker, Initiator, Escape]         1      1
# 89   [Carry, Support, Pusher, Disabler, Initiator, ...         1      0
# 90                 [Support, Nuker, Disabler, Jungler]         1      1
# 91                            [Support, Escape, Nuker]         0      1
# 92         [Support, Nuker, Durable, Disabler, Pusher]         1      1
# 93                    [Carry, Escape, Disabler, Nuker]         1      1
# 94                          [Carry, Disabler, Durable]         1      0
# 95                  [Carry, Pusher, Disabler, Durable]         1      0
# 96       [Durable, Initiator, Disabler, Nuker, Escape]         1      1
# 97                [Initiator, Disabler, Nuker, Escape]         1      1
# 98                            [Nuker, Durable, Escape]         0      1
# 99                  [Carry, Durable, Initiator, Nuker]         0      1
# 100                       [Initiator, Disabler, Nuker]         1      1
# 101                         [Support, Nuker, Disabler]         1      1
# 102                          [Support, Carry, Durable]         0      0
# 103              [Initiator, Disabler, Nuker, Durable]         1      1
# 104       [Carry, Disabler, Initiator, Durable, Nuker]         1      1
# 105                                  [Nuker, Disabler]         1      1
# 106        [Carry, Escape, Nuker, Disabler, Initiator]         1      1
# 107      [Nuker, Escape, Disabler, Initiator, Durable]         1      1
# 108        [Support, Nuker, Disabler, Durable, Escape]         1      1
# 109                             [Carry, Pusher, Nuker]         0      1
# 110      [Support, Nuker, Initiator, Escape, Disabler]         1      1
# 111                 [Support, Nuker, Disabler, Escape]         1      1
# 112                         [Support, Disabler, Nuker]         1      1
# 113                             [Carry, Escape, Nuker]         0      1
# 114               [Carry, Escape, Disabler, Initiator]         1      0
# 119                 [Support, Nuker, Disabler, Escape]         1      1
# 120  [Carry, Nuker, Disabler, Durable, Escape, Init...         1      1
# 121                 [Support, Nuker, Disabler, Escape]         1      1
#
#      Carry  Initiator  Escape  Durable  Support  Pusher  Jungler
# id
# 1        1          0       1        0        0       0        0
# 2        0          1       0        1        0       0        1
# 3        0          0       0        1        1       0        0
# 4        1          1       0        0        0       0        1
# 5        0          0       0        0        1       0        1
# 6        1          0       0        0        0       1        0
# 7        0          1       0        0        1       0        0
# 8        1          0       1        0        0       1        0
# 9        1          0       1        0        1       0        0
# 10       1          0       1        1        0       0        0
# 11       1          0       0        0        0       0        0
# 12       1          0       1        0        0       1        0
# 13       0          1       1        0        0       0        0
# 14       0          1       0        1        0       0        0
# 15       1          0       0        1        0       1        0
# 16       0          1       1        0        1       0        1
# 17       1          1       1        0        0       0        0
# 18       1          1       0        1        0       0        0
# 19       1          1       0        1        0       1        0
# 20       0          1       1        0        1       0        0
# 21       1          0       1        0        1       0        0
# 22       0          0       0        0        0       0        0
# 23       1          1       0        1        1       0        0
# 25       1          0       0        0        1       0        0
# 26       0          1       0        0        1       0        0
# 27       0          1       0        0        1       1        0
# 28       1          1       1        1        0       0        0
# 29       0          1       0        1        0       0        0
# 30       0          0       0        0        1       0        0
# 31       0          0       0        0        1       0        0
# ..     ...        ...     ...      ...      ...     ...      ...
# 88       0          1       1        0        0       0        0
# 89       1          1       1        0        1       1        0
# 90       0          0       0        0        1       0        1
# 91       0          0       1        0        1       0        0
# 92       0          0       0        1        1       1        0
# 93       1          0       1        0        0       0        0
# 94       1          0       0        1        0       0        0
# 95       1          0       0        1        0       1        0
# 96       0          1       1        1        0       0        0
# 97       0          1       1        0        0       0        0
# 98       0          0       1        1        0       0        0
# 99       1          1       0        1        0       0        0
# 100      0          1       0        0        0       0        0
# 101      0          0       0        0        1       0        0
# 102      1          0       0        1        1       0        0
# 103      0          1       0        1        0       0        0
# 104      1          1       0        1        0       0        0
# 105      0          0       0        0        0       0        0
# 106      1          1       1        0        0       0        0
# 107      0          1       1        1        0       0        0
# 108      0          0       1        1        1       0        0
# 109      1          0       0        0        0       1        0
# 110      0          1       1        0        1       0        0
# 111      0          0       1        0        1       0        0
# 112      0          0       0        0        1       0        0
# 113      1          0       1        0        0       0        0
# 114      1          1       1        0        0       0        0
# 119      0          0       1        0        1       0        0
# 120      1          1       1        1        0       0        0
# 121      0          0       1        0        1       0        0
#
# [116 rows x 13 columns]
