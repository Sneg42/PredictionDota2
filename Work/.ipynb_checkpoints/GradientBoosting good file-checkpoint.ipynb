# %%
import pandas as pd
import numpy as np
import math
import helper
import time
import datetime
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC, SVR

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score, LeaveOneOut, ShuffleSplit, train_test_split, GridSearchCV 
from sklearn.feature_selection import SelectPercentile, SelectFromModel
import pickle

# %% [markdown]
# # Подгрузка всех таблиц с данными по матчям

# %%
# дф с матчами и рейтингом каждой команды с патча 7.01 для Премиум
df_rating_teams_Premium = pd.read_csv('../tabel/table from Datdota/Rating teams/PREMIUM (with double Infamous) 7.00+ to 12.02.18.csv', index_col=0)
# удалить повторяющиеся матчи с Infamous, и сделать реиндекс 
df_rating_teams_Premium = df_rating_teams_Premium.drop(1).reset_index().drop('index', axis=1)

# # ДФ с KDA героев для всех (с данными с патча6,88-7,09 и до дня матча)
# df_KDA_hereos = pd.read_csv('../tabel/table from Datdota/KDA/data from 6.88+ heroes 7.00+ to 12.02.18.csv', index_col=0)
# ДФ с KDA героев для всех (с данными с патча 6,74-7,09 и до дня матча)
df_KDA_hereos = pd.read_csv('../tabel/table from Datdota/KDA/Heroes/'+
                            'data from 6.74-7.09 with last day match. 7.00+ to 12.02.18.csv', index_col=0)
# # ДФ с KDA героев для всех (с данными с патча 6,74-7,09 и до 2018.05.06)
# df_KDA_hereos = pd.read_csv('../tabel/table from Datdota/KDA/Heroes/'+
#                             'data from 6.74-7.09 wit last day 2018.05.06. 7.00+ to 12.02.18.csv', index_col=0)

# ДФ c KDA героев для каждой команды индивидуально
df_KDA_hereos_teams = pd.read_csv('../tabel/table from Datdota/KDA/Teams/'+
                                  'data from 6.88+ heroes for teams 7.00+ to 12.02.18.csv', index_col=0)
# выбросить столбцы с номерами героев
df_KDA_hereos = df_KDA_hereos.drop(['radiant_H1_hero', 'radiant_H2_hero', 'radiant_H3_hero', 'radiant_H4_hero', 'radiant_H5_hero',
                                    'dire_H1_hero', 'dire_H2_hero', 'dire_H3_hero', 'dire_H4_hero', 'dire_H5_hero'], axis=1)
df_KDA_hereos_teams = df_KDA_hereos_teams.drop(['radiant_H1_hero', 'radiant_H2_hero', 'radiant_H3_hero', 'radiant_H4_hero', 
                                    'radiant_H5_hero', 'dire_H1_hero', 'dire_H2_hero', 'dire_H3_hero', 'dire_H4_hero', 
                                                'dire_H5_hero'], axis=1)

# # ДФ с контрпиками (head-to-head) с 6,74-7,09 и до дня матча
# df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
#                 'data from 6.74-7.09 before day of match. 7.00+ to 12.02.18.csv'), index_col=0)
# # ДФ с контрпиками (head-to-head) с 6,88-7,09 и до дня матча
# df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
#                 'data from 6.74-7.09 with last day 2018.05.06. 7.00+ to 12.02.18.csv'), index_col=0)
# ДФ с контрпиками (head-to-head) с 6,74-7,09 и до 2018.05.06
df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
                'data from 6.74-7.09 with last day 2018.05.06. 7.00+ to 12.02.18.csv'), index_col=0)
# # ДФ с контрпиками (head-to-head) с 6.88-7,09 и до 2018.05.06
# df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
#                 'data from 6.88-7.09 with last day 2018.05.06. 7.00+ to 12.02.18.csv'), index_col=0)

# ДФ с типом героев
df_type_heroes = pd.read_csv('../tabel/table from Datdota/Sum features carry, support, nucker/'+
                             'PREMIUM 7.00+ to 12.02.18.csv', index_col=0)

# ДФ с метовыми героями
df_meta_heroes = pd.read_csv('../tabel/table from Datdota/AvgElo Meta and Signatures Heroes/'+
                             'Meta 7.00+ to 12.02.18.csv', index_col=0)

# ДФ с сигнатурками
df_signatures_heroes = pd.read_csv('../tabel/table from Datdota/AvgElo Meta and Signatures Heroes/'+
                                   'Sigantures 7.00+ to 12.02.18.csv', index_col=0)

# %% [markdown]
# # Создание основного ДФ для обучения и предсказания

# %%
# Соединение всех данных в один ДФ
# main = pd.merge(df_rating_teams_Premium, df_KDA_hereos, left_on='match_id', right_on='match_id',how='left')
# main = pd.merge(main, df_KDA_hereos_teams, left_on='match_id', right_on='match_id',how='left')

main = pd.merge(df_rating_teams_Premium, df_contrpick, left_on='match_id', right_on='match_id',how='left')

# main = pd.merge(main, df_contrpick, left_on='match_id', right_on='match_id',how='left')
# main = pd.merge(main, df_type_heroes, left_on='match_id', right_on='match_id',how='left')
main = pd.merge(main, df_meta_heroes, left_on='match_id', right_on='match_id',how='left')
main = pd.merge(main, df_signatures_heroes, left_on='match_id', right_on='match_id',how='left')

# # удаление не нужных колонок для обучения
main = main.drop(['match_id', 'start_time', 'radiant_team_id', 'radiant_score', 'dire_team_id',
           'dire_score', 'radiant_name', 'dire_name'], axis=1)
len(main)
# Out:
# 3729

# %%
# main.info()

# %%
# Оставляю только важные фичи, убираю из рейтинга команд ело32 и ело64
main = main.drop(main.loc[:, 'radiant_current_elo32':'radiant_thirtyDayAvg_elo64'], axis=1)
main = main.drop(main.loc[:, 'dire_current_elo32':'dire_thirtyDayAvg_elo64'], axis=1)

# %%
# Заполнить пустые значения на 0
main = main.fillna(0)

# # убрать пустые ячейки
# main = main.dropna()

# %%
len(main)
# Out:
# 3729

# %% [markdown]
# # Создание обучающих и тестовых данных

# %%
# удалть имена команд и сделать обучающие данные и ответы
X = main.drop(['radiant_win'], axis=1)
y = main['radiant_win']

# СДЕЛАТЬ 1 или 0 вместо true false
y = y.astype(int)

# деление на тестовые и обучающую выборку
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=0)

# %% [markdown]
# # Решетчатый поиск на Gradient Bosting

# %%
# %%time
# Праметры GB
# param_grid = {'n_estimators': [25, 50, 100, 150], 'max_depth': [10, 25, 50, 100],
#               'max_features': [50, 100, 200, 300]}
param_grid = {'n_estimators': [100], 'max_depth': [10],
              'max_features': [40]}
grid_search_GB = GridSearchCV(GradientBoostingClassifier(), param_grid, cv=5, n_jobs=-1)

grid_search_GB.fit(X_train,y_train)


print("Наилучшие значения параметров: {}".format(grid_search_GB.best_params_))
print('----------------------------------------------------------------------')
print(classification_report(y_test, grid_search_GB.predict(X_test), target_names=['dire_win', 'radiant_win']))
# Out:
# Наилучшие значения параметров: {'max_depth': 10, 'max_features': 40, 'n_estimators': 100}
# ----------------------------------------------------------------------
#              precision    recall  f1-score   support
#
#    dire_win       0.73      0.72      0.73       452
# radiant_win       0.74      0.75      0.75       481
#
# avg / total       0.74      0.74      0.74       933
#
# Wall time: 17.7 s

# %%
# %%time
# Праметры GB
# param_grid = {'n_estimators': [25, 50, 100, 150], 'max_depth': [10, 25, 50, 100],
#               'max_features': [50, 100, 200, 300]}
param_grid = {'n_estimators': [100], 'max_depth': [10],
              'max_features': [40]}
grid_search_GB = GridSearchCV(GradientBoostingClassifier(), param_grid, cv=5, n_jobs=-1)

grid_search_GB.fit(X_train,y_train)


print("Наилучшие значения параметров со всеми фичами: {}".format(grid_search_GB.best_params_))
print('----------------------------------------------------------------------')
print(classification_report(y_test, grid_search_GB.predict(X_test), target_names=['dire_win', 'radiant_win']))
# Out:
# Наилучшие значения параметров со всеми фичами: {'max_depth': 10, 'max_features': 40, 'n_estimators': 100}
# ----------------------------------------------------------------------
#              precision    recall  f1-score   support
#
#    dire_win       0.73      0.72      0.72       452
# radiant_win       0.74      0.75      0.74       481
#
# avg / total       0.73      0.73      0.73       933
#
# Wall time: 19.1 s

# %%
# # save the model to disk
# filename = 'grid_search_GB_model_Patch7.00+_2018.05.06.sav'
# pickle.dump(grid_search_GB, open(filename, 'wb'))

# %%
# %%time
# ДАННЫЕ ПО HEAD-TO-HEAD ДЛЯ ВСЕХ ПАТЧЕЙ ДО ПРЕДЫДУЩЕГО ДНЯ МАТЧЯ
import xgboost as xgb
# fit model no training data
model_allData_dayMatch = xgb.XGBClassifier()
model_allData_dayMatch.fit(X_train, y_train)
print (model_allData_dayMatch.score(X_test, y_test))
# Out:
# 0.733118971061
# Wall time: 4.89 s

# %%
# save the model to disk
filename = 'Xgboost_model_allData_dayMatch.sav'
pickle.dump(model_allData_dayMatch, open(filename, 'wb'))

# %%
test_gb = pickle.load(open(filename, 'rb'))
test_gb.score(X_test, y_test)
# Out:
# 0.66559485530546625

# %%
# %%time
# ДАННЫЕ ПО HEAD-TO-HEAD ДЛЯ ПАТЧЕЙ 6,88-7,09 ДО ПРЕДЫДУЩЕГО ДНЯ МАТЧЯ
import xgboost as xgb
# fit model no training data
model_patch700_dayMatch = xgb.XGBClassifier()
model_patch700_dayMatch.fit(X_train, y_train)
print (model_patch700_dayMatch.score(X_test, y_test))

# %%
# %%time
# ДАННЫЕ ПО HEAD-TO-HEAD С ПАТЧА 6,74-7,09 ДО 2018.05.06
import xgboost as xgb
# fit model no training data
model_allData_allDay = xgb.XGBClassifier()
model_allData_allDay.fit(X_train, y_train)
print (model_allData_allDay.score(X_test, y_test))
# Out:
# 0.739549839228
# Wall time: 234 ms

# %%
# %%time
# ДАННЫЕ ПО HEAD-TO-HEAD С ПАТЧА 7.00-7,09 ДО 2018.05.06
import xgboost as xgb
# fit model no training data
model_patch700_allDay = xgb.XGBClassifier()
model_patch700_allDay.fit(X_train, y_train)
print (model_patch700_allDay.score(X_test, y_test))

# %%
model = model_allData_allDay

# %% [markdown]
# # Проверка правильности данных

# %%
# main.loc[1500, 'radiant_H1elo_vs_enemies':]

# %%
import datetime
datetime.date.fromtimestamp(1502233763) - datetime.timedelta(1)
# Out:
# datetime.date(2017, 8, 8)

# %%
df_meta_heroes[df_meta_heroes['match_id'] == 3274564960]

# %% [markdown]
# # Работа с фичами

# %%
best_GB = model
# предсказания
predict_GB = best_GB.predict(X_test)
# матрица ошибок
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_test, predict_GB)
confusion
# Out:
# array([[336, 116],
#        [127, 354]], dtype=int64)

# %%
# f1-мера
from sklearn.metrics import f1_score
f1_score(y_test, predict_GB)
# Out:
# 0.74447949526813884

# %%
print(classification_report(y_test, predict_GB, target_names=['dire_win', 'radiant_win']))
# Out:
#              precision    recall  f1-score   support
#
#    dire_win       0.73      0.74      0.73       452
# radiant_win       0.75      0.74      0.74       481
#
# avg / total       0.74      0.74      0.74       933

# %%
# в RandomForestClassifier есть predict_proba, но нет decision_function
precision_gb, recall_gb, thresholds_gb = metrics.precision_recall_curve(
y_test, best_GB.predict_proba(X_test)[:, 1])

plt.plot(precision_gb, recall_gb, label="gb")
close_default_gb = np.argmin(np.abs(thresholds_gb - 0.5))
plt.plot(precision_gb[close_default_gb], recall_gb[close_default_gb], 'o', c='k',
         markersize=10, label="порог 0.5 rf", fillstyle="none", mew=2)
plt.xlabel("Точность")
plt.ylabel("Полнота")
plt.legend(loc="best")
plt.show()

# %%
y_pred_lower_threshold = best_GB.predict_proba(X_test)[:,1] > .5
print (classification_report(y_test, y_pred_lower_threshold))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.74      0.73       452
#           1       0.75      0.74      0.74       481
#
# avg / total       0.74      0.74      0.74       933

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, best_GB.predict_proba(X_test)[:,1])
plt.plot(fpr, tpr, label='ROC-кривая')
plt.xlabel('FPR')
plt.ylabel('TPR')
# находим пороговое значение ближайшее к нулю
close_zero = np.argmin(np.abs(threshold))
plt.plot(fpr[close_zero], tpr[close_zero], 'o', markersize=10, label='порог 0', fillstyle='none', c='k', mew=2)
plt.legend(loc='best')
plt.show()

# %%
gb_auc = metrics.roc_auc_score(y_test, best_GB.predict_proba(X_test)[:,1])
print('AUC для градиентного бустинга - {:.3f}'.format(gb_auc))
# Out:
# AUC для градиентного бустинга - 0.817

# %% [markdown]
# # Оценка качества признаков

# %%
# используем f_classif (по умолчанию)
# и SelectPercentile, чтобы выбрать 50% признаков
select = SelectPercentile(percentile=50)
select.fit(X_train, y_train)
X_train_selected = select.transform(X_train)

print("форма массива X_train: {}".format(X_train.shape))
print("форма массива X_train_selected: {}".format(X_train_selected.shape))
# Out:
# форма массива X_train: (2796, 66)
# форма массива X_train_selected: (2796, 33)

# %%
mask = select.get_support()
print (mask)
# визуализируем булевы значения: черный - true, булый - false
plt.matshow(mask.reshape(1, -1), cmap='gray_r')
plt.xlabel('Индекс')
# Out:
# [ True False  True False  True  True False  True False  True  True  True
#  False False  True False  True  True  True False  True False  True  True
#  False  True False  True  True  True  True False  True False  True  True
#   True  True  True  True  True  True  True  True  True  True False False
#  False False False False False False False False False False False False
#  False False False False False False]
# Text(0.5,0,'Индекс')

# %%
X_test_selected = select.transform(X_test)
print ('Правильность со всеми признаками: {:.3f}'.format(best_GB.score(X_test, y_test)))
best_GB_selected_70 = xgb.XGBClassifier(max_depth=20)
best_GB_selected_70.fit(X_train_selected, y_train)
print ('Правильность с 50% признаками: {:.3f}'.format(best_GB_selected_70.score(X_test_selected, y_test)))
# Out:
# Правильность со всеми признаками: 0.740
# Правильность с 50% признаками: 0.733

# %%
# важность признаков в бустинге

n_features = X_train.shape[1]
plt.figure(figsize=(20,50))
plt.barh(range(n_features), best_GB.feature_importances_, align='center')
plt.yticks(np.arange(n_features), X_train.columns)
plt.xlabel('Важность признака')
plt.ylabel('Признаки')
plt.show()

# %%
n_features = X_train_selected.shape[1]
plt.figure(figsize=(20,100))
plt.barh(range(n_features), best_GB_selected_70.feature_importances_, align='center')
plt.yticks(np.arange(n_features))
plt.xlabel('Важность признака')
plt.ylabel('Признаки')
plt.show()

# %% [markdown]
# # Проверка на новых данных

# %%
# дф с матчами и рейтингом каждой команды с патча 7.01 для Премиум
df_rating_teams_Premium = pd.read_csv('../tabel/table from Datdota/Rating teams/'+
                                      'PREMIUM on 13.02.18 to 12.03.18.csv', index_col=0)

# # ДФ с KDA героев для всех
# df_KDA_hereos = pd.read_csv('../tabel/table from Datdota/KDA/Heroes/'+
#                             'data from 6.88+ heroes 7.00+ to 12.02.18.csv', index_col=0)

# # ДФ c KDA героев для каждой команды индивидуально
# df_KDA_hereos_teams = pd.read_csv('../tabel/table from Datdota/KDA/Teams/'+
#                                   'data from 6.88+ heroes for teams 7.00+ to 12.02.18.csv', index_col=0)
# # выбросить столбцы с номерами героев
# df_KDA_hereos = df_KDA_hereos.drop(['radiant_H1_hero', 'radiant_H2_hero', 'radiant_H3_hero', 'radiant_H4_hero', 'radiant_H5_hero',
#                                     'dire_H1_hero', 'dire_H2_hero', 'dire_H3_hero', 'dire_H4_hero', 'dire_H5_hero'], axis=1)
# df_KDA_hereos_teams = df_KDA_hereos_teams.drop(['radiant_H1_hero', 'radiant_H2_hero', 'radiant_H3_hero', 'radiant_H4_hero', 
#                                     'radiant_H5_hero', 'dire_H1_hero', 'dire_H2_hero', 'dire_H3_hero', 'dire_H4_hero', 
#                                                 'dire_H5_hero'], axis=1)

# # ДФ с контрпиками (head-to-head) с 6,74-7,09 и до дня матча
# df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
#                 'data from 6.74-7.10 before day of match. on 13.02.18 to 12.03.18.csv'), index_col=0)
# # ДФ с контрпиками (head-to-head) с 6,88-7,09 и до дня матча
# # df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
# #                 'data from 6.74-7.09 with last day 2018.05.06. 7.00+ to 12.02.18.csv'), index_col=0)
# ДФ с контрпиками (head-to-head) с 6,74-7,09 и до 2018.05.06
df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
                'data from 6.74-7.10 with last day 2018.05.06. on 13.02.18 to 12.03.18.csv'), index_col=0)
# # # ДФ с контрпиками (head-to-head) с 6.88-7,09 и до 2018.05.06
# # df_contrpick = pd.read_csv(('../tabel/table from Datdota/Heah-to-head Contrpicks/'+
# #                 'data from 6.88-7.09 with last day 2018.05.06. 7.00+ to 12.02.18.csv'), index_col=0)

# # ДФ с типом героев
# df_type_heroes = pd.read_csv('../tabel/table from Datdota/Sum features carry, support, nucker/'+
#                              'PREMIUM 7.00+ to 12.02.18.csv', index_col=0)

# ДФ с метовыми героями
df_meta_heroes = pd.read_csv('../tabel/table from Datdota/AvgElo Meta and Signatures Heroes/'+
                             'Meta on 13.02.18 to 12.03.18.csv', index_col=0)

# ДФ с сигнатурками
df_signatures_heroes = pd.read_csv('../tabel/table from Datdota/AvgElo Meta and Signatures Heroes/'+
                                   'Signatures on 13.02.18 to 12.03.18.csv', index_col=0)

# %%
# Соединение всех данных в один ДФ
# test = pd.merge(df_rating_teams_Premium, df_KDA_hereos, left_on='match_id', right_on='match_id',how='left')
# test = pd.merge(test, df_KDA_hereos_teams, left_on='match_id', right_on='match_id',how='left')

test = pd.merge(df_rating_teams_Premium, df_contrpick, left_on='match_id', right_on='match_id',how='left')

# test = pd.merge(test, df_contrpick, left_on='match_id', right_on='match_id',how='left')
# test = pd.merge(test, df_type_heroes, left_on='match_id', right_on='match_id',how='left')
test = pd.merge(test, df_meta_heroes, left_on='match_id', right_on='match_id',how='left')
test = pd.merge(test, df_signatures_heroes, left_on='match_id', right_on='match_id',how='left')

# # удаление не нужных колонок для обучения
test = test.drop(['match_id', 'start_time', 'radiant_team_id', 'radiant_score', 'dire_team_id',
           'dire_score', 'radiant_name', 'dire_name', 'league_name'], axis=1)
test = test.drop(test.loc[:, 'radiant_H1':'dire_P5'], axis=1)
len(test)
test = test.dropna()

# Оставляю только важные фичи, убираю из рейтинга команд ело32 и ело64
test = test.drop(test.loc[:, 'radiant_current_elo32':'radiant_thirtyDayAvg_elo64'], axis=1)
test = test.drop(test.loc[:, 'dire_current_elo32':'dire_thirtyDayAvg_elo64'], axis=1)

# %%
# Создание контрольной выборки
# удалть имена команд и сделать обучающие данные и ответы
X_contr = test.drop(['radiant_win'], axis=1)
y_contr = test['radiant_win']

# СДЕЛАТЬ 1 или 0 вместо true false
y_contr = y_contr.astype(int)

# %%
# gb_auc_contr = metrics.roc_auc_score(y_contr, best_GB.predict_proba(X_contr)[:,1])
# print('AUC для градиентного бустинга - {:.3f}'.format(gb_auc_contr))

# %%
# y_contr_lower_threshold = best_GB.predict_proba(X_contr)[:,1] > .5
# print (classification_report(y_contr, y_contr_lower_threshold))

# %%
print(classification_report(y_contr, grid_search_GB.predict(X_contr), target_names=['dire_win', 'radiant_win']))
# Out:
#              precision    recall  f1-score   support
#
#    dire_win       0.66      0.69      0.68       164
# radiant_win       0.76      0.74      0.75       216
#
# avg / total       0.72      0.72      0.72       380
